# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this section is to develop the necessary data processing steps to modify the dataset for subsequent data analysis.
#
# The data processing steps are developed with the following goals:
# - The columns are in the correct data type
# - The dataset does not contain outliers
# - The dataset should contain newly created features
#
# It is important to note that the focus of this section is to create a dataset for the next step which is data visualization.
#
# As more insight is obtained, the dataset will be further modified.

# %% [markdown]
# # 2. Data Collection

# %% [markdown]
# The data is collected from insideairbnb.com. It is an activist webiste that periodically scrap airbnb's database for listing information.
#
# The following file is downloaded and unzipped into the file 'listings.csv' for analysis:
# http://data.insideairbnb.com/japan/kant%C5%8D/tokyo/2019-06-27/data/listings.csv.gz
#
# According to the information provided, the data is scraped on 2019/06/27.

# %% [markdown]
# The file *listings.csv* can be downloaded from: https://drive.google.com/open?id=17A535-0gvKU_Q2Fyw7H3T3UFiXbeKWAj

# %% [markdown]
# # 3. Initial Dataset Exploration

# %%
# import required packages
import numpy as np
import pandas as pd
import re
import datetime
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('data/listings.csv')
# Out:
# C:\Users\georg\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (61,62,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# The warning message indicates two columns (61,62) have mixed data types.

# %%
#Inspect those columns
df.iloc[:,[61,62,95]].head()
# Out:
#   weekly_price monthly_price jurisdiction_names
# 0    $2,000.00           NaN                NaN
# 1          NaN     $2,679.00                NaN
# 2      $397.00       $973.00                NaN
# 3          NaN           NaN                NaN
# 4          NaN     $4,766.00                NaN

# %% [markdown]
# It seems the mixed type is due to the dollar sign and NaN. This issue will be corrected in the data cleaning step.

# %% [markdown]
# First, explore the data set:

# %%
#Inspect number of rows and features
df.shape
# Out:
# (20769, 106)

# %% [markdown]
# There are 20,769 rows and and 106 features. Each row consists of a listing on airbnb in the Greater Toronto Area.

# %% [markdown]
# The features can be divided into the following 6 subcategories:
#
# 1. **Host information**: interaction, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified
# 2. **Property information**: name, summary, space, description, neighborhood_overview, notes, transit, access, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities,square_feet,jurisdiction_names, requires_license, license
# 3. **Booking information and policy**: experiences_offered, house_rules, price, weekly_price, monthly_price,security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated,  has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, is_business_travel_ready, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, instant_bookable
# 4. **Airbnb listing information**: id, listing_url, thumbnail_url, medium_url, picture_url, xl_picture_url
# 5. **Reviews**: number_of_reviews, number_of_reviews_ltm, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, reviews_per_month
# 6. **Web scraping information**: scrape_id, last_scraped

# %% [markdown]
# It is likely that not all features will be used for data analysis. Nonetheless, all features are kept for now. Given the moderate size (14066 rows x 106 features) of this dataset, keeping all the columns should not significantly impact memory and computational speed.
#
# Irrelevant features will be removed at the last step of the data cleaning process.
# Note that the dataset may need further processing for statistical analysis and machine learning.

# %% [markdown]
# # 4. Data Cleaning

# %% [markdown]
# ## 4.1 Features with Excessive Missing Values Removal

# %% [markdown]
# Features with excessive number of missing values are considered unuseful for data analysis, and is therefore removed.
# For this analysis, a threshold of 50% is set; i.e., features with 50% or greater of the values missing will be removed.

# %%
threshold = 0.5
remove_columns_NA = df.columns[df.isnull().sum()/df.shape[0] > threshold]
print(remove_columns_NA)
# Out:
# Index(['notes', 'thumbnail_url', 'medium_url', 'xl_picture_url',
#        'host_acceptance_rate', 'neighbourhood_group_cleansed', 'square_feet',
#        'weekly_price', 'monthly_price', 'license', 'jurisdiction_names'],
#       dtype='object')

# %%
df.drop(remove_columns_NA,axis=1,inplace=True)
df.shape
# Out:
# (20769, 95)

# %%
#Keep record of removed columns
removed_columns_record = []
removed_columns_record.append(remove_columns_NA)

# %% [markdown]
# After this step, 95 features remain.

# %% [markdown]
# ## 4.2 Data Type Correction

# %% [markdown]
# The purpose of this section is to ensure the data types of each columns are correct. The focus will be on boolean, numeric and categorical data types.

# %% [markdown]
# ### 4.2.1 Change column data type to boolean

# %% [markdown]
# A few columns are boolean, but the values are stored as string type, with values of 't' or 'f'.

# %%
col_to_boolean = ['host_is_superhost','host_has_profile_pic','host_identity_verified','is_location_exact','has_availability',
                  'requires_license','instant_bookable','is_business_travel_ready','require_guest_profile_picture',
                  'require_guest_phone_verification']

# %% [markdown]
# The following loop consists of three steps:
#     1. Create a dummy column to identify row with missing value for that feature (with column name of '[COL]_NA')
#     2. Fill missing values with the mode of that feature
#     3. Map the string values ('t' or 'f') to their boolean values (True or False)
# The first step is included to keep a record of rows with missing values.

# %%
# Change data type to boolean and add new column for NA values
d = {'f':False, 't':True}
for col in col_to_boolean:
    # add new column if needed
    if df[col].isnull().sum() > 0:
        df[col+'_NA'] = np.where(df[col].isnull(),True,False)
        m = df[col].mode().iloc[0]
        df[col] = df[col].fillna(m).map(d).astype('bool')
    else:
        df[col]=df[col].map(d).astype('bool')

# %%
df.shape
# Out:
# (20769, 98)

# %% [markdown]
# ### 4.2.2 Change column data type to numeric

# %% [markdown]
# A few numeric columns are in string format. It is necessary to convert them to numeric for data analysis.

# %%
col_to_numeric = ['price','security_deposit','cleaning_fee','extra_people']

# %%
for col in col_to_numeric:
    df[col] = df[col].str.replace('$','').str.replace(',','').astype(float)

# %%
df.host_response_rate = df.host_response_rate.str.replace('%','').astype(float)/100

# %% [markdown]
# ### 4.2.3 Change column data type to datetime

# %% [markdown]
# A few columns consist of datatime information, but are stored as string. It is necessary to convert them to datetime data type.

# %%
col_to_datetime = ['last_scraped','host_since','calendar_last_scraped','first_review','last_review']

# %%
for col in col_to_datetime:
    df[col] = pd.to_datetime(df[col])

# %% [markdown]
# ### 4.2.4 Change column data type to category

# %% [markdown]
# Some columns are categorical but are stored as string. It is necessary to convert them to categorial data type.

# %%
col_to_cat = ['host_response_time','property_type','room_type','bed_type','cancellation_policy']

# %%
for col in col_to_cat:
    df[col] = df[col].astype('category')

# %% [markdown]
# ## 4.3 Outliers Evaluation

# %% [markdown]
# It is important to ensure the data is accurate, and the presence of outliers is an indicator of inaccuarcy. In this section, outliers are identified and investigated.

# %%
numeric_features = [col for col in df.columns if df[col].dtype in ['int64','float64']]

# %%
print(numeric_features)
# Out:
# ['id', 'scrape_id', 'host_id', 'host_response_rate', 'host_listings_count', 'host_total_listings_count', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %% [markdown]
# The statistics of the data are inspected with the _describe_ method. Only data likely to be relevant to data analysis will be reviewed.

# %% [markdown]
# ### 4.3.1 Nightly prices and fees

# %%
df.loc[:,['price', 'security_deposit', 'cleaning_fee', 'extra_people']].describe()
# Out:
#               price  security_deposit  cleaning_fee  extra_people
# count  20769.000000      15867.000000  17385.000000  20769.000000
# mean     143.288074        327.501859     60.276445     14.162694
# std      234.157135        452.885745     49.732881     23.543072
# min        0.000000          0.000000      0.000000      0.000000
# 25%       64.000000        130.000000     25.000000      0.000000
# 50%      101.000000        250.000000     50.000000      8.000000
# 75%      160.000000        500.000000     80.000000     20.000000
# max    13422.000000       6711.000000    962.000000    403.000000

# %% [markdown]
# It can be seen that the maximum nightly price is \$13,422 which is very high. To ensure accuracy, listings with price over \$5,000 is further investigated.

# %%
df.loc[df.price > 5000.00,['id','listing_url','name','price']]
# Out:
#              id                            listing_url  \
# 6263   16039481  https://www.airbnb.com/rooms/16039481
# 6854   17330866  https://www.airbnb.com/rooms/17330866
# 8974   20653172  https://www.airbnb.com/rooms/20653172
# 19221  33983450  https://www.airbnb.com/rooms/33983450
# 19783  34470470  https://www.airbnb.com/rooms/34470470
# 19787  34471108  https://www.airbnb.com/rooms/34471108
#
#                                                     name    price
# 6263                           Art Collector's Penthouse  13422.0
# 6854        Toronto's Bloor West Village - High Park - B   5900.0
# 8974            Modern Upscale Condo in downtown Toronto  13000.0
# 19221  Executive family home near Casa Loma and ravines.   7500.0
# 19783  NEW! Executive 1 BR+Den Condo in Heart of Down...   9999.0
# 19787  1BR + 3 Queen BED. Sleeps 6 Condo in MapleLeaf...   9999.0

# %% [markdown]
# The URLs of the six listings are investigated, with the prices recorded below.

# %%
actual_price = [13078,78,13000,7500,174,224]
df_high_price = df.loc[df.price > 5000.00,['id','listing_url','name','price']]
df_high_price['actual_price'] = actual_price
df_high_price
# Out:
#              id                            listing_url  \
# 6263   16039481  https://www.airbnb.com/rooms/16039481
# 6854   17330866  https://www.airbnb.com/rooms/17330866
# 8974   20653172  https://www.airbnb.com/rooms/20653172
# 19221  33983450  https://www.airbnb.com/rooms/33983450
# 19783  34470470  https://www.airbnb.com/rooms/34470470
# 19787  34471108  https://www.airbnb.com/rooms/34471108
#
#                                                     name    price  \
# 6263                           Art Collector's Penthouse  13422.0
# 6854        Toronto's Bloor West Village - High Park - B   5900.0
# 8974            Modern Upscale Condo in downtown Toronto  13000.0
# 19221  Executive family home near Casa Loma and ravines.   7500.0
# 19783  NEW! Executive 1 BR+Den Condo in Heart of Down...   9999.0
# 19787  1BR + 3 Queen BED. Sleeps 6 Condo in MapleLeaf...   9999.0
#
#        actual_price
# 6263          13078
# 6854             78
# 8974          13000
# 19221          7500
# 19783           174
# 19787           224

# %% [markdown]
# For listing id 17330866, 34470470, and 34471108, there is a huge discrepancy between the listed price and the actual price found on the web. As such the three rows are removed.

# %%
# drop by index
for idx in (6854,19783,19787):
    df.drop(idx,inplace=True)

# %%
# Keep record of dropped columns
removed_indexes_record = []
removed_indexes_record.append([6854,19783,19787])

# %% [markdown]
# The security deposit shows a wide range, from \$0 up to \$6,711. It is an option available for the hosts to protect their properties, with the amount chosen by the host. Note that it is not the amount the customers need to pay upfront, but rather the max amount the host can claim in case of a dispute.
#
# The cleaning fee shows a wide range, from \$0 up to \$403. It is a one-time charge for every booking.
#
# The range of charge for additional guest (extra_people) is between \$0 and \$403. It is the charge applied for extra guests.
#
# Since those values are decided by the host, they are not outliers.

# %% [markdown]
# ### 4.3.2 Host Information

# %%
df.loc[:,['host_listings_count', 'host_total_listings_count','host_response_rate']].describe()
# Out:
#        host_listings_count  host_total_listings_count  host_response_rate
# count         20761.000000               20761.000000        15782.000000
# mean              5.613362                   5.613362            0.948663
# std              12.655650                  12.655650            0.152770
# min               0.000000                   0.000000            0.000000
# 25%               1.000000                   1.000000            1.000000
# 50%               2.000000                   2.000000            1.000000
# 75%               4.000000                   4.000000            1.000000
# max             179.000000                 179.000000            1.000000

# %% [markdown]
# The minimum host listings count is 0, which is counter-intuitive because the minimum count should be 1 for having a listing. The definition of this feature need to be explored.
#
# Also, it is suspected the two columns 'host_listings_count' and 'host_total_listings_count' are identical. If identical, the latter column will be dropped.

# %%
if df.host_listings_count.equals(df.host_total_listings_count) == True:
    print('The 2nd column is dropped because they are identical.')
    df=df.drop('host_total_listings_count',axis=1)
# Out:
# The 2nd column is dropped because they are identical.

# %%
#keep record of removed columns
removed_columns_record.append(['host_total_listings_count'])

# %% [markdown]
# ### 4.3.3 Geographical locations

# %%
df.loc[:,numeric_features[2:4]].describe()
# Out:
#             host_id  host_response_rate
# count  2.076600e+04        15782.000000
# mean   8.373210e+07            0.948663
# std    7.878565e+07            0.152770
# min    1.565000e+03            0.000000
# 25%    1.707799e+07            1.000000
# 50%    5.099545e+07            1.000000
# 75%    1.428543e+08            1.000000
# max    2.662243e+08            1.000000

# %% [markdown]
# The latitude and longitude values seem legit.

# %% [markdown]
# ### 4.3.4 Property information

# %%
df.loc[:,['accommodates', 'bathrooms', 'bedrooms', 'beds']].describe()
# Out:
#        accommodates     bathrooms      bedrooms          beds
# count  20766.000000  20751.000000  20758.000000  20743.000000
# mean       3.145671      1.251891      1.324887      1.689630
# std        2.034453      0.566297      0.877059      1.119205
# min        1.000000      0.000000      0.000000      0.000000
# 25%        2.000000      1.000000      1.000000      1.000000
# 50%        2.000000      1.000000      1.000000      1.000000
# 75%        4.000000      1.000000      2.000000      2.000000
# max       16.000000     10.000000     15.000000     17.000000

# %% [markdown]
# The data shows that the number of bathrooms, bedrooms and beds are highly right skewed. To explore these outliers:

# %%
df.loc[df.accommodates == 16].shape[0]
# Out:
# 60

# %% [markdown]
# It turns out there are 60 properties that can accommodate up to 16 people. So it is not that unusual.

# %%
df.loc[df.bathrooms == 10, ['listing_url','name','accommodates','bathrooms','bedrooms','beds','price']]
# Out:
#                                  listing_url  \
# 20422  https://www.airbnb.com/rooms/35063046
#
#                                    name  accommodates  bathrooms  bedrooms  \
# 20422  Modern Comfy in Downtown Toronto            12       10.0      12.0
#
#        beds  price
# 20422  12.0   75.0

# %%
df.loc[df.bedrooms == 15, ['listing_url','name','bathrooms','bedrooms','beds','price']]
# Out:
#                                  listing_url  \
# 16391  https://www.airbnb.com/rooms/30796225
#
#                                                  name  bathrooms  bedrooms  \
# 16391  4 LOFTS- 6000 SQ FT-2-15 bedrooms, 8 bathrooms        8.0      15.0
#
#        beds   price
# 16391  15.0  1000.0

# %%
df.loc[df.beds == 17, ['listing_url','name','bathrooms','bedrooms','beds','price']]
# Out:
#                                  listing_url  \
# 16058  https://www.airbnb.com/rooms/30366574
# 17704  https://www.airbnb.com/rooms/32394735
#
#                                                     name  bathrooms  bedrooms  \
# 16058  Spacious 13 bedroom House for Large Group & Ev...        6.0      13.0
# 17704  Spacious 13 bedroom House for Large Group & Ev...        6.0      13.0
#
#        beds  price
# 16058  17.0  999.0
# 17704  17.0  999.0

# %% [markdown]
# The numbers are verified by inspecting the listing websites.

# %% [markdown]
# ### 4.3.5 Booking Policy

# %%
df.loc[:,['guests_included', 'minimum_nights']].describe()
# Out:
#        guests_included  minimum_nights
# count     20766.000000    20766.000000
# mean          1.698305        6.293701
# std           1.380140       29.359315
# min           1.000000        1.000000
# 25%           1.000000        1.000000
# 50%           1.000000        2.000000
# 75%           2.000000        3.000000
# max          16.000000     1125.000000

# %% [markdown]
# The minimum stay of 1125 seems unreasonable. The listing url is visited to investigate further.

# %%
df.loc[df.minimum_nights==1125,['id','listing_url','name','price','minimum_nights']]
# Out:
#             id                            listing_url  \
# 2815   8001458   https://www.airbnb.com/rooms/8001458
# 4994  13883417  https://www.airbnb.com/rooms/13883417
#
#                                                 name  price  minimum_nights
# 2815              Clean private ensuite with parking   75.0            1125
# 4994  Bright, modern condo in hip King West downtown  101.0            1125

# %% [markdown]
# There are 2 listings with this minimum nights of stay. In the first listing (id# 8001458), the minimum nights of stay is listed as 1125, while no information is provided in the second listing.
#
# It is likely that the host is relocated for prolonged period, so they require this unusually long stay.  They are believed to be neither outliers nor data inaccuracy.

# %% [markdown]
# ### 4.3.6 Availability

# %%
df.loc[:,['availability_30', 'availability_60', 'availability_90', 'availability_365']].describe()
# Out:
#        availability_30  availability_60  availability_90  availability_365
# count     20766.000000     20766.000000     20766.000000      20766.000000
# mean          8.251132        19.985409        33.809833        120.692334
# std           9.973650        21.022031        32.377932        124.258138
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         0.000000          0.000000
# 50%           4.000000        12.000000        27.000000         79.000000
# 75%          14.000000        37.000000        64.000000        213.000000
# max          30.000000        60.000000        90.000000        365.000000

# %% [markdown]
# The values seem legit.

# %% [markdown]
# ### 4.3.7 Reviews

# %%
df.loc[:,['number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']].describe()
# Out:
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# count       20766.000000           20766.000000          16494.000000
# mean           25.532794              12.398921             94.436522
# std            46.689798              20.488780              8.024220
# min             0.000000               0.000000             20.000000
# 25%             1.000000               0.000000             93.000000
# 50%             7.000000               3.000000             97.000000
# 75%            28.000000              16.000000            100.000000
# max           717.000000             185.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count            16484.000000               16486.000000
# mean                 9.660216                   9.434005
# std                  0.788494                   0.946481
# min                  2.000000                   2.000000
# 25%                 10.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           16483.000000                 16486.000000
# mean                9.736395                     9.760099
# std                 0.712774                     0.705204
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  reviews_per_month
# count            16478.000000         16481.000000       16783.000000
# mean                 9.704394             9.483526           1.865436
# std                  0.655651             0.851319           2.141966
# min                  2.000000             2.000000           0.010000
# 25%                 10.000000             9.000000           0.350000
# 50%                 10.000000            10.000000           1.010000
# 75%                 10.000000            10.000000           2.660000
# max                 10.000000            10.000000          17.140000

# %% [markdown]
# All values seems legit.

# %% [markdown]
# ### 4.4 Missing values imputation

# %% [markdown]
# In this section, the missing values of the both numeric and categorical features will be addressed. Again, only features likely relevant to data analysis will be investigated.

# %% [markdown]
# ### 4.4.1 Numeric features

# %%
num_with_na = []
numeric_features = [col for col in df.columns if df[col].dtype in ['int64','float64']]

for col in numeric_features:
    if df[col].isnull().sum() > 0:
        print(f'{col} has {df[col].isnull().sum()} missing values')
        num_with_na.append(col)
# Out:
# host_response_rate has 4984 missing values
# host_listings_count has 5 missing values
# bathrooms has 15 missing values
# bedrooms has 8 missing values
# beds has 23 missing values
# security_deposit has 4902 missing values
# cleaning_fee has 3384 missing values
# review_scores_rating has 4272 missing values
# review_scores_accuracy has 4282 missing values
# review_scores_cleanliness has 4280 missing values
# review_scores_checkin has 4283 missing values
# review_scores_communication has 4280 missing values
# review_scores_location has 4288 missing values
# review_scores_value has 4285 missing values
# reviews_per_month has 3983 missing values

# %% [markdown]
# It is uncertain why the features host listings count, host response rate, bathrooms, bedrooms, beds are missing.
# To impute those features, the following steps are used:
#     1. Create a new column to record the rows with missing values (with name [COL]_NA)
#     2. Impute columns with column median

# %%
for col in ['host_listings_count','bathrooms','host_response_rate','bedrooms','beds']:
    df[col+'_NA'] = np.where(df[col].isnull(),True, False)
    m = df[col].median()
    df[col].fillna(m,inplace=True)

# %% [markdown]
# Missing security deposits and cleaning fees are likely due the hosts' decision to not include one, which is equivalent to a value of 0. Io impute, the following stems are used:
#     1. Create a new column to record the rows with missing values (with name [COL]_NA)
#     2. Impute columns with value of 0

# %%
for col in ['security_deposit','cleaning_fee']:
    df[col+'_NA'] = np.where(df[col].isnull(),True, False)
    df[col].fillna(0,inplace=True)

# %% [markdown]
# For review scores, the missing values are likely due to the fact that the listings are new with no or few customers. To impute, the following steps are used:
#     1. Create a new column to record the rows with missing values (with name [COL]_NA)
#     2. Impute columns with median

# %%
for col in ['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin',
           'review_scores_communication','review_scores_location','review_scores_value','reviews_per_month']:
    df[col+'_NA'] = np.where(df[col].isnull(),True, False)
    df[col].fillna(df[col].median(),inplace=True)

# %% [markdown]
# ### 4.4.2 Categorical Features

# %%
#generate column list for category features
cat_features = [col for col in df.columns if df[col].dtype.name == "category"]
print(cat_features)
# Out:
# ['host_response_time', 'property_type', 'room_type', 'bed_type', 'cancellation_policy']

# %%
cat_with_na = []
for col in cat_features:
    if df[col].isnull().sum() > 0:
        print(f'{col} has {df[col].isnull().sum()} missing values')
        cat_with_na.append(col)
# Out:
# host_response_time has 4984 missing values

# %% [markdown]
# To impute for host response time, the following steps are used:
#     1. Create a new column to record the rows with missing values (with name [COL]_NA)
#     2. Impute columns with mode

# %%
for col in cat_with_na:
    df[col+"_NA"] = np.where(df[col].isnull(),1,0)
    df[col].fillna(df[col].mode().iloc[0],inplace=True)

# %% [markdown]
# ### 4.4.3 Datetime Features

# %%
df.host_since.dtypes
# Out:
# dtype('<M8[ns]')

# %%
#generate column list for datetime features
dt_features = [col for col in df.columns if df[col].dtype == "<M8[ns]"]
print(dt_features)
# Out:
# ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']

# %%
dt_with_na = []
for col in dt_features:
    if df[col].isnull().sum() > 0:
        print(f'{col} has {df[col].isnull().sum()} missing values')
        dt_with_na.append(col)
# Out:
# host_since has 5 missing values
# first_review has 3983 missing values
# last_review has 3983 missing values

# %% [markdown]
# To impute for the missing values, the following steps are used:
#     1. Create a new column to record the rows with missing values (with name [COL]_NA)
#     2. Impute columns with median (quantile = 0.5)

# %%
for col in dt_with_na:
    df[col+"_NA"] = np.where(df[col].isnull(),1,0)
    df[col].fillna(df[col].quantile(0.5),inplace=True)

# %% [markdown]
# # 5 New Feature Creation

# %% [markdown]
# ## 5.1 Dummy Variable for Amenities

# %% [markdown]
# The column _amenities_ contains a string of available amenities for reach listing.

# %%
df.amenities.head()
# Out:
# 0    {TV,Internet,Wifi,"Air conditioning",Kitchen,"...
# 1    {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 2    {Internet,Wifi,"Pets live on this property",Ca...
# 3    {Internet,Wifi,"Air conditioning",Kitchen,"Fre...
# 4    {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# Name: amenities, dtype: object

# %% [markdown]
# First, create a new column with the string converted to a list:

# %%
df['amenities_list'] = df['amenities'].str.lower().str.replace('[{}"]','').str.split(',')

# %%
df['amenities_list'].head()
# Out:
# 0    [tv, internet, wifi, air conditioning, kitchen...
# 1    [tv, cable tv, internet, wifi, air conditionin...
# 2    [internet, wifi, pets live on this property, c...
# 3    [internet, wifi, air conditioning, kitchen, fr...
# 4    [tv, cable tv, internet, wifi, air conditionin...
# Name: amenities_list, dtype: object

# %%
#Create amenities set
amenities_set = set()
for i in df['amenities_list']:
    amenities_set.update(i)
print(amenities_set)
# Out:
# {'', 'formal dining area', 'bathtub with bath chair', 'espresso machine', 'cat(s)', 'high-resolution computer monitor', 'stove', 'iron', 'hot water', 'private hot tub', 'essentials', 'wide entrance for guests', 'heated towel rack', 'double oven', 'private pool', 'walk-in shower', 'pillow-top mattress', 'garden or backyard', 'rain shower', 'table corner guards', 'lockbox', 'ski-in/ski-out', 'netflix', 'mobile hoist', 'dryer', 'soaking tub', 'pets live on this property', 'internet', 'hair dryer', 'memory foam mattress', 'wide clearance to shower', 'game console', 'crib', 'bathtub', 'bathroom essentials', 'warming drawer', 'patio or balcony', 'beach view', 'sauna', 'changing table', 'private gym', 'elevator', 'toilet paper', 'smart tv', 'cooking basics', 'translation missing: en.hosting_amenity_50', 'roll-in shower', 'accessible-height toilet', 'shared hot tub', 'bbq grill', 'pocket wifi', 'outdoor kitchen', 'wifi', 'ceiling hoist', 'touchless faucets', 'hot tub', 'babysitter recommendations', 'fax machine', 'window guards', 'heated floors', 'building staff', 'waterfront', 'wine cooler', 'refrigerator', 'shared pool', 'luggage dropoff allowed', 'high chair', 'bidet', 'long term stays allowed', 'dog(s)', 'hangers', 'extra pillows and blankets', ' toilet', 'ceiling fan', 'air conditioning', 'paid parking on premises', 'ev charger', 'fire extinguisher', 'well-lit path to entrance', 'suitable for events', 'family/kid friendly', 'free parking on premises', 'buzzer/wireless intercom', 'carbon monoxide detector', 'fire pit', 'cleaning before checkout', 'free street parking', 'outdoor seating', 'wheelchair accessible', 'balcony', 'single level home', 'gym', 'breakfast table', 'pool', 'shampoo', 'projector and screen', 'private living room', 'translation missing: en.hosting_amenity_49', 'children’s books and toys', 'air purifier', '24-hour check-in', 'heat lamps', 'convection oven', 'terrace', 'amazon echo', 'smoking allowed', 'wide entryway', 'dvd player', 'paid parking off premises', 'beachfront', 'stair gates', 'pool toys', 'coffee maker', 'electric profiling bed', 'hammock', 'self check-in', 'outdoor parking', 'murphy bed', 'lock on bedroom door', 'safety card', 'steam oven', 'dishes and silverware', 'smart lock', 'heating', 'hot water kettle', 'keypad', 'mountain view', 'first aid kit', 'bath towel', 'hbo go', 'printer', 'no stairs or steps to enter', 'en suite bathroom', 'room-darkening shades', 'wide doorway to guest bathroom', 'private entrance', 'doorman', 'washer / dryer', 'tv', 'microwave', 'ground floor access', 'mudroom', 'pack ’n play/travel crib', 'exercise equipment', 'central air conditioning', 'gas oven', 'washer', 'oven', 'shower chair', 'cable tv', 'pool with pool hoist', 'shared gym', 'breakfast', 'firm mattress', 'pets allowed', 'private bathroom', 'indoor fireplace', 'tennis court', 'laptop friendly workspace', 'bed linens', 'wide hallways', 'accessible-height bed', 'beach essentials', 'brick oven', 'baby monitor', 'mini fridge', 'kitchenette', 'pool cover', 'bedroom comforts', 'full kitchen', 'smoke detector', 'flat path to guest entrance', 'sound system', 'fireplace guards', 'children’s dinnerware', 'extra space around shower and toilet', 'sun loungers', 'day bed', 'other', 'host greets you', 'baby bath', 'ethernet connection', 'outlet covers', 'wide entrance', 'extra space around bed', 'fixed grab bars for toilet', 'alfresco bathtub', 'dishwasher', 'kitchen', 'other pet(s)', 'jetted tub', 'disabled parking spot', 'stand alone steam shower', 'body soap', 'lake access', 'fixed grab bars for shower', 'standing valet'}

# %%
len(amenities_set)
# Out:
# 197

# %% [markdown]
# In total, there are 197 unique amenities. There one with null entry (1st item) which will be removed.

# %%
amenities_set.remove('')

# %% [markdown]
# Next, dummy variables are created for each item and each listing. Values of _True_ and _False_ will be assigned according to their availability.

# %%
for item in amenities_set:
    df['amenities_' + item] = df.amenities_list.apply(lambda x: True if item in x else False)

# %%
for item in amenities_set:
    print(f'Number of listings with {item}: {df["amenities_" + item].sum()}')
# Out:
# Number of listings with formal dining area: 54
# Number of listings with bathtub with bath chair: 42
# Number of listings with espresso machine: 56
# Number of listings with cat(s): 420
# Number of listings with high-resolution computer monitor: 11
# Number of listings with stove: 8522
# Number of listings with iron: 14650
# Number of listings with hot water: 12263
# Number of listings with private hot tub: 5
# Number of listings with essentials: 19751
# Number of listings with wide entrance for guests: 1309
# Number of listings with heated towel rack: 7
# Number of listings with double oven: 8
# Number of listings with private pool: 3
# Number of listings with walk-in shower: 72
# Number of listings with pillow-top mattress: 48
# Number of listings with garden or backyard: 2660
# Number of listings with rain shower: 54
# Number of listings with table corner guards: 42
# Number of listings with lockbox: 3360
# Number of listings with ski-in/ski-out: 11
# Number of listings with netflix: 141
# Number of listings with mobile hoist: 2
# Number of listings with dryer: 16554
# Number of listings with soaking tub: 57
# Number of listings with pets live on this property: 1076
# Number of listings with internet: 5002
# Number of listings with hair dryer: 15316
# Number of listings with memory foam mattress: 57
# Number of listings with wide clearance to shower: 387
# Number of listings with game console: 299
# Number of listings with crib: 396
# Number of listings with bathtub: 2473
# Number of listings with bathroom essentials: 333
# Number of listings with warming drawer: 15
# Number of listings with patio or balcony: 4587
# Number of listings with beach view: 8
# Number of listings with sauna: 6
# Number of listings with changing table: 147
# Number of listings with private gym: 2
# Number of listings with elevator: 8674
# Number of listings with toilet paper: 328
# Number of listings with smart tv: 129
# Number of listings with cooking basics: 8123
# Number of listings with translation missing: en.hosting_amenity_50: 2801
# Number of listings with roll-in shower: 145
# Number of listings with accessible-height toilet: 658
# Number of listings with shared hot tub: 11
# Number of listings with bbq grill: 1646
# Number of listings with pocket wifi: 299
# Number of listings with outdoor kitchen: 4
# Number of listings with wifi: 20381
# Number of listings with ceiling hoist: 3
# Number of listings with touchless faucets: 3
# Number of listings with hot tub: 3122
# Number of listings with babysitter recommendations: 313
# Number of listings with fax machine: 4
# Number of listings with window guards: 151
# Number of listings with heated floors: 33
# Number of listings with building staff: 831
# Number of listings with waterfront: 631
# Number of listings with wine cooler: 10
# Number of listings with refrigerator: 9432
# Number of listings with shared pool: 18
# Number of listings with luggage dropoff allowed: 3914
# Number of listings with high chair: 756
# Number of listings with bidet: 6
# Number of listings with long term stays allowed: 6473
# Number of listings with dog(s): 473
# Number of listings with hangers: 17602
# Number of listings with extra pillows and blankets: 5837
# Number of listings with  toilet: 387
# Number of listings with ceiling fan: 39
# Number of listings with air conditioning: 17743
# Number of listings with paid parking on premises: 2598
# Number of listings with ev charger: 181
# Number of listings with fire extinguisher: 10747
# Number of listings with well-lit path to entrance: 1939
# Number of listings with suitable for events: 480
# Number of listings with family/kid friendly: 6562
# Number of listings with free parking on premises: 8338
# Number of listings with buzzer/wireless intercom: 1543
# Number of listings with carbon monoxide detector: 16669
# Number of listings with fire pit: 8
# Number of listings with cleaning before checkout: 933
# Number of listings with free street parking: 2014
# Number of listings with outdoor seating: 76
# Number of listings with wheelchair accessible: 1166
# Number of listings with balcony: 69
# Number of listings with single level home: 1375
# Number of listings with gym: 6301
# Number of listings with breakfast table: 91
# Number of listings with pool: 3821
# Number of listings with shampoo: 16613
# Number of listings with projector and screen: 5
# Number of listings with private living room: 2592
# Number of listings with translation missing: en.hosting_amenity_49: 2252
# Number of listings with children’s books and toys: 868
# Number of listings with air purifier: 4
# Number of listings with 24-hour check-in: 1959
# Number of listings with heat lamps: 2
# Number of listings with convection oven: 69
# Number of listings with terrace: 50
# Number of listings with amazon echo: 11
# Number of listings with smoking allowed: 673
# Number of listings with wide entryway: 909
# Number of listings with dvd player: 21
# Number of listings with paid parking off premises: 4761
# Number of listings with beachfront: 137
# Number of listings with stair gates: 195
# Number of listings with pool toys: 1
# Number of listings with coffee maker: 7184
# Number of listings with electric profiling bed: 12
# Number of listings with hammock: 1
# Number of listings with self check-in: 7233
# Number of listings with outdoor parking: 20
# Number of listings with murphy bed: 14
# Number of listings with lock on bedroom door: 6247
# Number of listings with safety card: 2705
# Number of listings with steam oven: 6
# Number of listings with dishes and silverware: 8700
# Number of listings with smart lock: 915
# Number of listings with heating: 20106
# Number of listings with hot water kettle: 162
# Number of listings with keypad: 2139
# Number of listings with mountain view: 5
# Number of listings with first aid kit: 7929
# Number of listings with bath towel: 328
# Number of listings with hbo go: 17
# Number of listings with printer: 21
# Number of listings with no stairs or steps to enter: 2338
# Number of listings with en suite bathroom: 78
# Number of listings with room-darkening shades: 1094
# Number of listings with wide doorway to guest bathroom: 564
# Number of listings with private entrance: 7014
# Number of listings with doorman: 1143
# Number of listings with washer / dryer: 2
# Number of listings with tv: 14671
# Number of listings with microwave: 8672
# Number of listings with ground floor access: 2
# Number of listings with mudroom: 11
# Number of listings with pack ’n play/travel crib: 877
# Number of listings with exercise equipment: 32
# Number of listings with central air conditioning: 74
# Number of listings with gas oven: 34
# Number of listings with washer: 16809
# Number of listings with oven: 8175
# Number of listings with shower chair: 37
# Number of listings with cable tv: 4735
# Number of listings with pool with pool hoist: 22
# Number of listings with shared gym: 26
# Number of listings with breakfast: 1850
# Number of listings with firm mattress: 19
# Number of listings with pets allowed: 2604
# Number of listings with private bathroom: 7
# Number of listings with indoor fireplace: 2056
# Number of listings with tennis court: 1
# Number of listings with laptop friendly workspace: 15622
# Number of listings with bed linens: 7880
# Number of listings with wide hallways: 1309
# Number of listings with accessible-height bed: 779
# Number of listings with beach essentials: 92
# Number of listings with brick oven: 1
# Number of listings with baby monitor: 74
# Number of listings with mini fridge: 17
# Number of listings with kitchenette: 39
# Number of listings with pool cover: 2
# Number of listings with bedroom comforts: 333
# Number of listings with full kitchen: 400
# Number of listings with smoke detector: 19534
# Number of listings with flat path to guest entrance: 1161
# Number of listings with sound system: 53
# Number of listings with fireplace guards: 100
# Number of listings with children’s dinnerware: 404
# Number of listings with extra space around shower and toilet: 509
# Number of listings with sun loungers: 15
# Number of listings with day bed: 29
# Number of listings with other: 1628
# Number of listings with host greets you: 3239
# Number of listings with baby bath: 182
# Number of listings with ethernet connection: 1312
# Number of listings with outlet covers: 232
# Number of listings with wide entrance: 1033
# Number of listings with extra space around bed: 1051
# Number of listings with fixed grab bars for toilet: 46
# Number of listings with alfresco bathtub: 2
# Number of listings with dishwasher: 5876
# Number of listings with kitchen: 19139
# Number of listings with other pet(s): 57
# Number of listings with jetted tub: 7
# Number of listings with disabled parking spot: 421
# Number of listings with stand alone steam shower: 7
# Number of listings with body soap: 328
# Number of listings with lake access: 1377
# Number of listings with fixed grab bars for shower: 104
# Number of listings with standing valet: 3

# %% [markdown]
# In total, 196 new columns are created.

# %% [markdown]
# ## 5.2 City Names

# %% [markdown]
# In addition to _longitude_ and _latitude_, some other columns may also contain useful geographical information, namely _street_, _city_, _zipcode_, _market_, and *smart_location*.

# %%
df.street.unique()
# Out:
# array(['Toronto, ON, Canada', 'toronto, ON, Canada', 'Toronto, 1, Canada',
#        'Guelph, ON, Canada', 'Etobicoke, ON, Canada',
#        'Toronto, Ont, Canada', 'Toronto, ON, ON, Canada',
#        'North York, Toronto, ON, Canada', '토론토, 온타리오, Canada',
#        'Scarborough, ON, Canada', '多伦多, 安大略省, Canada',
#        'North York, ON, Canada', 'Vaughan, ON, Canada', 'Toronto, Canada',
#        'scarborough, ON, Canada', 'Toronto, On, Canada',
#        'Etobicoke , ON, Canada', 'Mississauga, ON, Canada',
#        'Toronto, , ON, Canada', 'North york, ON, Canada',
#        'Toronto , ON, Canada', '多伦多, ON, Canada',
#        'Toronto, Ontario, CA, ON, Canada', 'North York , ON, Canada',
#        'SCARBOROUGH, ON, Canada', 'York, ON, Canada',
#        'Markham, ON, Canada', 'Toronto M5S 2L6, ON, Canada',
#        'Scarborough , ON, Canada', 'ONTARIO , TORONTO, Canada',
#        'Vaughan , ON, Canada', 'North york - Toronto , ON, Canada',
#        'Scarborough , Toronto  , ON, Canada', 'toronto, ontario, Canada',
#        'ON, ON, Canada', 'Thornhill , ON, Canada', 'Pickering, ON, Canada'], dtype=object)

# %%
df.city.unique()
# Out:
# array(['Toronto', 'toronto', 'Guelph', 'Etobicoke', 'Toronto, ON',
#        'North York, Toronto', '토론토', 'Scarborough', '多伦多', 'North York',
#        'Vaughan', 'scarborough', 'Etobicoke ', 'Mississauga', 'Toronto, ',
#        'North york', 'Toronto ', 'Toronto, Ontario, CA', 'North York ',
#        'SCARBOROUGH', 'York', 'Markham', 'Toronto M5S 2L6', 'Scarborough ',
#        'ONTARIO ', 'Vaughan ', 'North york - Toronto ',
#        'Scarborough , Toronto  ', nan, 'Thornhill ', 'Pickering'], dtype=object)

# %%
df.market.unique()
# Out:
# array(['Toronto', 'Montreal', 'Paris', nan, 'Other (International)'], dtype=object)

# %%
df.smart_location.unique()
# Out:
# array(['Toronto, Canada', 'toronto, Canada', 'Guelph, Canada',
#        'Etobicoke, Canada', 'Toronto, ON, Canada',
#        'North York, Toronto, Canada', '토론토, Canada', 'Scarborough, Canada',
#        '多伦多, Canada', 'North York, Canada', 'Vaughan, Canada',
#        'scarborough, Canada', 'Etobicoke , Canada', 'Mississauga, Canada',
#        'Toronto, , Canada', 'North york, Canada', 'Toronto , Canada',
#        'Toronto, Ontario, CA, Canada', 'North York , Canada',
#        'SCARBOROUGH, Canada', 'York, Canada', 'Markham, Canada',
#        'Toronto M5S 2L6, Canada', 'Scarborough , Canada',
#        'ONTARIO , Canada', 'Vaughan , Canada',
#        'North york - Toronto , Canada', 'Scarborough , Toronto  , Canada',
#        'ON, Canada', 'Thornhill , Canada', 'Pickering, Canada'], dtype=object)

# %% [markdown]
# The features of *street*, *city*, *market* and *smart_location* are not all that useful.

# %% [markdown]
# Explore *zipcode*:

# %%
df.zipcode.nunique()
# Out:
# 6925

# %%
# Top 20 zipcode by count
df.zipcode.value_counts(dropna=False).head(20)
# Out:
# NaN        365
# M5J 0B1    344
# M5R 1C4    199
# M5V        191
# M5V 0E9    159
# M5J        158
# M5V 4A9    130
# M5J 0A6    107
# M5V 0J9     99
# M5V 0G6     96
# M5J 0A7     96
# M5V 4A2     93
# M5V 4B2     91
# M6J         90
# M5V 0J8     77
# M5J 2Z2     76
# M5V 4A5     73
# M5H 0B1     72
# M2N         65
# M5J 0A1     62
# Name: zipcode, dtype: int64

# %% [markdown]
# The zipcode consists of 365 missing values. Also, it consists of both the 6-digit format (FSA + LDU) and the 3-digit format. FSA stands for **Forward Sortation Area** and LDU stands for **Local Delivery Unit**. The FSA can be used to identify the city of the listing.

# %% [markdown]
# First, a new column with just the fsa is created:

# %%
df['fsa'] = df.zipcode.str.slice(stop=3).str.upper()

# %%
df['fsa'].nunique()
# Out:
# 116

# %%
# display top 30 FSA by count
df['fsa'].value_counts(dropna=False).head(30)
# Out:
# M5V    2696
# M5J    1187
# M6J     998
# M6K     810
# M2N     761
# M6H     668
# M5R     660
# M5A     641
# M4Y     635
# M6G     595
# M5T     566
# M6P     393
# M5S     387
# M5B     368
# NaN     365
# M4M     331
# M6R     318
# M4L     311
# M2M     287
# M4C     272
# M2J     265
# M4J     258
# M4K     248
# M4X     226
# M6E     226
# M8V     223
# M3J     220
# M5H     182
# M4S     179
# M4E     179
# Name: fsa, dtype: int64

# %% [markdown]
# Next, the FSA values are matched with the City. The website https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M contains the FSA codes along with the corresponding regions in Greater Toronto Area.  The data table was copied and pasted into a csv file.

# %% [markdown]
# The file *toronto_fsa.csv* can be downloaded from https://drive.google.com/open?id=1-ImaFEoNC-TQji5LxDtAdH7jlJ2q1A0P

# %%
toronto_fsa = pd.read_csv('data/toronto_fsa.csv')
toronto_fsa.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
#create a dictionary with postcode as key and borough (city) as dictionary
fsa_dict = {i:j for i,j in zip(toronto_fsa.Postcode, toronto_fsa.Borough)}

#create new column that maps the FSA to the city name
df['city_fsa'] = np.nan
df['city_fsa'] = df.fsa.map(fsa_dict)

# %%
# The counts for each assigned city
df.city_fsa.value_counts(dropna=False)
# Out:
# Downtown Toronto    7936
# West Toronto        3360
# North York          2749
# Central Toronto     1426
# Scarborough         1359
# Etobicoke           1083
# East Toronto        1069
# York                 707
# East York            671
# NaN                  403
# Not assigned           2
# Queen's Park           1
# Name: city_fsa, dtype: int64

# %%
# The number of listings not assigned a city
df.city_fsa.isnull().sum()
# Out:
# 403

# %%
df.loc[df.city_fsa.isnull(),'fsa'].value_counts(dropna=False)
# Out:
# NaN    365
# L3T     12
# L4J      8
# [NO      3
# L1W      2
# M        2
# G7H      1
# 2V5      1
# L5E      1
# SEC      1
# L4W      1
# L0J      1
# M15      1
# N1E      1
# MP6      1
# L3S      1
# ON       1
# Name: fsa, dtype: int64

# %% [markdown]
# With unknown or ambiguous zipcode, it is difficult to locate the property. To impute the missing *city_fsa* values:
#     1. A column to identify the missing value is created
#     2. The missing value is imputed with 'Other'

# %%
df['city_fsa_NA'] = np.where(df['city_fsa'].isnull(),True,False)
df['city_fsa'].fillna('Other',inplace=True)

# %% [markdown]
# ## 5.3 Date time Difference from Reference Day

# %% [markdown]
# The number of months since the recorded events can be a feature more useful than the dates. A reference date of 2019/6/27, which is the date this dataset was scrapped is chosen.

# %%
ref_date = datetime.datetime(2019,6,27)

# %%
(ref_date - df['host_since'][1]).days
# Out:
# 3657

# %%
dt_col = ['host_since','first_review','last_review']
for col in dt_col:
    df['days_since'+col] = df[col].apply(lambda x: (ref_date - x).days)

# %% [markdown]
# # 6 Removal Irrelevant Variables

# %% [markdown]
# As the final step, features that are likely irrelevant for data analysis are removed.

# %%
df.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  1419  https://www.airbnb.com/rooms/1419  20190604202502   2019-06-05
# 1  8077  https://www.airbnb.com/rooms/8077  20190604202502   2019-06-06
#
#                                  name  \
# 0     Beautiful home in amazing area!
# 1  Downtown Harbourfront Private Room
#
#                                              summary  \
# 0  This large, family home is located in one of T...
# 1  Guest room in a luxury condo with access to al...
#
#                                                space  \
# 0  Visit Toronto with this fabulous furnished hom...
# 1  My husband and I are both artists. I give pain...
#
#                                          description experiences_offered  \
# 0  This large, family home is located in one of T...                none
# 1  Guest room in a luxury condo with access to al...                none
#
#                                neighborhood_overview  \
# 0  The apartment is located in the Ossington stri...
# 1                                                NaN
#
#                                              transit  \
# 0  All forms of public transportation are easily ...
# 1                                                NaN
#
#                                       access  \
# 0  The whole house and garden are available.
# 1                                        NaN
#
#                                          interaction  \
# 0  We will be out of town, but fully accessible b...
# 1                                                NaN
#
#                                          house_rules  \
# 0  This is our much-loved family home. We expect ...
# 1                                 No smoking please.
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/im/pictures/76206750/d...     1565
# 1  https://a0.muscache.com/im/pictures/11780344/1...    22795
#
#                                   host_url       host_name host_since  \
# 0   https://www.airbnb.com/users/show/1565       Alexandra 2008-08-08
# 1  https://www.airbnb.com/users/show/22795  Kathie & Larry 2009-06-22
#
#               host_location  \
# 0  Toronto, Ontario, Canada
# 1  Toronto, Ontario, Canada
#
#                                           host_about  host_response_time  \
# 0  I live in Toronto, Canada with my husband and ...      within an hour
# 1  My husband and I have been airbnb host for alm...  a few days or more
#
#    host_response_rate  host_is_superhost  \
# 0                 1.0              False
# 1                 0.0              False
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/1565/profile_...
# 1  https://a0.muscache.com/im/pictures/9a077853-c...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/1565/profile_...   Commercial Drive
# 1  https://a0.muscache.com/im/pictures/9a077853-c...       Harbourfront
#
#    host_listings_count                                 host_verifications  \
# 0                  1.0  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 1                  2.0          ['email', 'phone', 'facebook', 'reviews']
#
#    host_has_profile_pic  host_identity_verified               street  \
# 0                  True                    True  Toronto, ON, Canada
# 1                  True                   False  Toronto, ON, Canada
#
#       neighbourhood             neighbourhood_cleansed     city state zipcode  \
# 0   Little Portugal                    Little Portugal  Toronto    ON     M6J
# 1  Downtown Toronto  Waterfront Communities-The Island  Toronto    ON     M5J
#
#     market   smart_location country_code country  latitude  longitude  \
# 0  Toronto  Toronto, Canada           CA  Canada  43.64617  -79.42451
# 1  Toronto  Toronto, Canada           CA  Canada  43.64105  -79.37628
#
#    is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0              False         House  Entire home/apt            10        3.0
# 1               True     Apartment     Private room             2        1.5
#
#    bedrooms  beds  bed_type  \
# 0       5.0   7.0  Real Bed
# 1       1.0   1.0  Real Bed
#
#                                            amenities  price  security_deposit  \
# 0  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...  468.0            1000.0
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  100.0            2679.0
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0         150.0                1           0.0               4
# 1           0.0                1           0.0             180
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             730                       4                       4
# 1             365                     180                     180
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                     730                     730                     4.0
# 1                     365                     365                   180.0
#
#    maximum_nights_avg_ntm calendar_updated  has_availability  availability_30  \
# 0                   730.0    16 months ago              True                0
# 1                   365.0     9 months ago              True                0
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0                0                0                 0            2019-06-05
# 1                0                0                 0            2019-06-06
#
#    number_of_reviews  number_of_reviews_ltm first_review last_review  \
# 0                  7                      0   2015-07-19  2017-12-04
# 1                169                      0   2009-08-20  2013-08-27
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                 100.0                    10.0                       10.0
# 1                  97.0                    10.0                       10.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                   10.0                         10.0                    10.0
#
#    review_scores_value  requires_license  instant_bookable  \
# 0                 10.0             False             False
# 1                 10.0             False              True
#
#    is_business_travel_ready          cancellation_policy  \
# 0                     False  strict_14_with_grace_period
# 1                     False  strict_14_with_grace_period
#
#    require_guest_profile_picture  require_guest_phone_verification  \
# 0                          False                             False
# 1                          False                              True
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0               0.15
# 1                                            0               1.42
#
#    host_is_superhost_NA  host_has_profile_pic_NA  host_identity_verified_NA  \
# 0                 False                    False                      False
# 1                 False                    False                      False
#
#    host_listings_count_NA  bathrooms_NA  host_response_rate_NA  bedrooms_NA  \
# 0                   False         False                   True        False
# 1                   False         False                  False        False
#
#    beds_NA  security_deposit_NA  cleaning_fee_NA  review_scores_rating_NA  \
# 0    False                False            False                    False
# 1    False                False             True                    False
#
#    review_scores_accuracy_NA  review_scores_cleanliness_NA  \
# 0                      False                         False
# 1                      False                         False
#
#    review_scores_checkin_NA  review_scores_communication_NA  \
# 0                     False                           False
# 1                     False                           False
#
#    review_scores_location_NA  review_scores_value_NA  reviews_per_month_NA  \
# 0                      False                   False                 False
# 1                      False                   False                 False
#
#    host_response_time_NA  host_since_NA  first_review_NA  last_review_NA  \
# 0                      1              0                0               0
# 1                      0              0                0               0
#
#                                       amenities_list  \
# 0  [tv, internet, wifi, air conditioning, kitchen...
# 1  [tv, cable tv, internet, wifi, air conditionin...
#
#    amenities_formal dining area  amenities_bathtub with bath chair  \
# 0                         False                              False
# 1                         False                              False
#
#    amenities_espresso machine  amenities_cat(s)  \
# 0                       False             False
# 1                       False             False
#
#    amenities_high-resolution computer monitor  amenities_stove  \
# 0                                       False            False
# 1                                       False            False
#
#    amenities_iron  amenities_hot water  amenities_private hot tub  \
# 0           False                False                      False
# 1           False                False                      False
#
#    amenities_essentials  amenities_wide entrance for guests  \
# 0                  True                               False
# 1                 False                               False
#
#    amenities_heated towel rack  amenities_double oven  amenities_private pool  \
# 0                        False                  False                   False
# 1                        False                  False                   False
#
#    amenities_walk-in shower  amenities_pillow-top mattress  \
# 0                     False                          False
# 1                     False                          False
#
#    amenities_garden or backyard  amenities_rain shower  \
# 0                         False                  False
# 1                         False                  False
#
#    amenities_table corner guards  amenities_lockbox  amenities_ski-in/ski-out  \
# 0                          False              False                     False
# 1                          False              False                     False
#
#    amenities_netflix  amenities_mobile hoist  amenities_dryer  \
# 0              False                   False             True
# 1              False                   False            False
#
#    amenities_soaking tub  amenities_pets live on this property  \
# 0                  False                                 False
# 1                  False                                 False
#
#    amenities_internet  amenities_hair dryer  amenities_memory foam mattress  \
# 0                True                 False                           False
# 1                True                 False                           False
#
#    amenities_wide clearance to shower  amenities_game console  amenities_crib  \
# 0                               False                   False           False
# 1                               False                   False           False
#
#    amenities_bathtub  amenities_bathroom essentials  amenities_warming drawer  \
# 0              False                          False                     False
# 1              False                          False                     False
#
#    amenities_patio or balcony  amenities_beach view  amenities_sauna  \
# 0                       False                 False            False
# 1                       False                 False            False
#
#    amenities_changing table  amenities_private gym  amenities_elevator  \
# 0                     False                  False               False
# 1                     False                  False                True
#
#    amenities_toilet paper  amenities_smart tv  amenities_cooking basics  \
# 0                   False               False                     False
# 1                   False               False                     False
#
#    amenities_translation missing: en.hosting_amenity_50  \
# 0                                              False
# 1                                              False
#
#    amenities_roll-in shower  amenities_accessible-height toilet  \
# 0                     False                               False
# 1                     False                               False
#
#    amenities_shared hot tub  amenities_bbq grill  amenities_pocket wifi  \
# 0                     False                False                  False
# 1                     False                False                  False
#
#    amenities_outdoor kitchen  amenities_wifi  amenities_ceiling hoist  \
# 0                      False            True                    False
# 1                      False            True                    False
#
#    amenities_touchless faucets  amenities_hot tub  \
# 0                        False              False
# 1                        False              False
#
#    amenities_babysitter recommendations  amenities_fax machine  \
# 0                                 False                  False
# 1                                 False                  False
#
#    amenities_window guards  amenities_heated floors  amenities_building staff  \
# 0                    False                    False                     False
# 1                    False                    False                     False
#
#    amenities_waterfront  amenities_wine cooler  amenities_refrigerator  \
# 0                 False                  False                   False
# 1                 False                  False                   False
#
#    amenities_shared pool  amenities_luggage dropoff allowed  \
# 0                  False                              False
# 1                  False                              False
#
#    amenities_high chair  amenities_bidet  amenities_long term stays allowed  \
# 0                 False            False                              False
# 1                 False            False                              False
#
#    amenities_dog(s)  amenities_hangers  amenities_extra pillows and blankets  \
# 0             False              False                                 False
# 1             False              False                                 False
#
#    amenities_ toilet  amenities_ceiling fan  amenities_air conditioning  \
# 0              False                  False                        True
# 1              False                  False                        True
#
#    amenities_paid parking on premises  amenities_ev charger  \
# 0                               False                 False
# 1                               False                 False
#
#    amenities_fire extinguisher  amenities_well-lit path to entrance  \
# 0                         True                                False
# 1                        False                                False
#
#    amenities_suitable for events  amenities_family/kid friendly  \
# 0                          False                           True
# 1                          False                          False
#
#    amenities_free parking on premises  amenities_buzzer/wireless intercom  \
# 0                               False                               False
# 1                                True                                True
#
#    amenities_carbon monoxide detector  amenities_fire pit  \
# 0                               False               False
# 1                               False               False
#
#    amenities_cleaning before checkout  amenities_free street parking  \
# 0                               False                          False
# 1                               False                          False
#
#    amenities_outdoor seating  amenities_wheelchair accessible  \
# 0                      False                            False
# 1                      False                            False
#
#    amenities_balcony  amenities_single level home  amenities_gym  \
# 0              False                        False          False
# 1              False                        False           True
#
#    amenities_breakfast table  amenities_pool  amenities_shampoo  \
# 0                      False           False               True
# 1                      False            True               True
#
#    amenities_projector and screen  amenities_private living room  \
# 0                           False                          False
# 1                           False                          False
#
#    amenities_translation missing: en.hosting_amenity_49  \
# 0                                              False
# 1                                              False
#
#    amenities_children’s books and toys  amenities_air purifier  \
# 0                                False                   False
# 1                                False                   False
#
#    amenities_24-hour check-in  amenities_heat lamps  \
# 0                       False                 False
# 1                       False                 False
#
#    amenities_convection oven  amenities_terrace  amenities_amazon echo  \
# 0                      False              False                  False
# 1                      False              False                  False
#
#    amenities_smoking allowed  amenities_wide entryway  amenities_dvd player  \
# 0                      False                    False                 False
# 1                      False                    False                 False
#
#    amenities_paid parking off premises  amenities_beachfront  \
# 0                                False                 False
# 1                                False                 False
#
#    amenities_stair gates  amenities_pool toys  amenities_coffee maker  \
# 0                  False                False                   False
# 1                  False                False                   False
#
#    amenities_electric profiling bed  amenities_hammock  \
# 0                             False              False
# 1                             False              False
#
#    amenities_self check-in  amenities_outdoor parking  amenities_murphy bed  \
# 0                    False                      False                 False
# 1                    False                      False                 False
#
#    amenities_lock on bedroom door  amenities_safety card  \
# 0                           False                  False
# 1                           False                  False
#
#    amenities_steam oven  amenities_dishes and silverware  \
# 0                 False                            False
# 1                 False                            False
#
#    amenities_smart lock  amenities_heating  amenities_hot water kettle  \
# 0                 False               True                       False
# 1                 False               True                       False
#
#    amenities_keypad  amenities_mountain view  amenities_first aid kit  \
# 0             False                    False                     True
# 1             False                    False                    False
#
#    amenities_bath towel  amenities_hbo go  amenities_printer  \
# 0                 False             False              False
# 1                 False             False              False
#
#    amenities_no stairs or steps to enter  amenities_en suite bathroom  \
# 0                                  False                        False
# 1                                  False                        False
#
#    amenities_room-darkening shades  amenities_wide doorway to guest bathroom  \
# 0                            False                                     False
# 1                            False                                     False
#
#    amenities_private entrance  amenities_doorman  amenities_washer / dryer  \
# 0                       False              False                     False
# 1                       False               True                     False
#
#    amenities_tv  amenities_microwave  amenities_ground floor access  \
# 0          True                False                          False
# 1          True                False                          False
#
#    amenities_mudroom  amenities_pack ’n play/travel crib  \
# 0              False                               False
# 1              False                               False
#
#    amenities_exercise equipment  amenities_central air conditioning  \
# 0                         False                               False
# 1                         False                               False
#
#    amenities_gas oven  amenities_washer  amenities_oven  \
# 0               False              True           False
# 1               False             False           False
#
#    amenities_shower chair  amenities_cable tv  amenities_pool with pool hoist  \
# 0                   False               False                           False
# 1                   False                True                           False
#
#    amenities_shared gym  amenities_breakfast  amenities_firm mattress  \
# 0                 False                False                    False
# 1                 False                False                    False
#
#    amenities_pets allowed  amenities_private bathroom  \
# 0                   False                       False
# 1                   False                       False
#
#    amenities_indoor fireplace  amenities_tennis court  \
# 0                        True                   False
# 1                       False                   False
#
#    amenities_laptop friendly workspace  amenities_bed linens  \
# 0                                False                 False
# 1                                False                 False
#
#    amenities_wide hallways  amenities_accessible-height bed  \
# 0                    False                            False
# 1                    False                            False
#
#    amenities_beach essentials  amenities_brick oven  amenities_baby monitor  \
# 0                       False                 False                   False
# 1                       False                 False                   False
#
#    amenities_mini fridge  amenities_kitchenette  amenities_pool cover  \
# 0                  False                  False                 False
# 1                  False                  False                 False
#
#    amenities_bedroom comforts  amenities_full kitchen  \
# 0                       False                   False
# 1                       False                   False
#
#    amenities_smoke detector  amenities_flat path to guest entrance  \
# 0                      True                                  False
# 1                      True                                  False
#
#    amenities_sound system  amenities_fireplace guards  \
# 0                   False                       False
# 1                   False                       False
#
#    amenities_children’s dinnerware  \
# 0                            False
# 1                            False
#
#    amenities_extra space around shower and toilet  amenities_sun loungers  \
# 0                                           False                   False
# 1                                           False                   False
#
#    amenities_day bed  amenities_other  amenities_host greets you  \
# 0              False            False                      False
# 1              False            False                      False
#
#    amenities_baby bath  amenities_ethernet connection  \
# 0                False                          False
# 1                False                          False
#
#    amenities_outlet covers  amenities_wide entrance  \
# 0                    False                    False
# 1                    False                    False
#
#    amenities_extra space around bed  amenities_fixed grab bars for toilet  \
# 0                             False                                 False
# 1                             False                                 False
#
#    amenities_alfresco bathtub  amenities_dishwasher  amenities_kitchen  \
# 0                       False                 False               True
# 1                       False                 False              False
#
#    amenities_other pet(s)  amenities_jetted tub  \
# 0                   False                 False
# 1                   False                 False
#
#    amenities_disabled parking spot  amenities_stand alone steam shower  \
# 0                            False                               False
# 1                            False                               False
#
#    amenities_body soap  amenities_lake access  \
# 0                False                  False
# 1                False                  False
#
#    amenities_fixed grab bars for shower  amenities_standing valet  fsa  \
# 0                                 False                     False  M6J
# 1                                 False                     False  M5J
#
#            city_fsa  city_fsa_NA  days_sincehost_since  \
# 0      West Toronto        False                  3975
# 1  Downtown Toronto        False                  3657
#
#    days_sincefirst_review  days_sincelast_review
# 0                    1439                    570
# 1                    3598                   2130

# %%
#remove irrelevant string columns
l_str = []
for col in df.columns:
    if df[col].dtype == 'O':
        l_str.append(col)
print(l_str)
# Out:
# ['listing_url', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'transit', 'access', 'interaction', 'house_rules', 'picture_url', 'host_url', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'amenities', 'calendar_updated', 'amenities_list', 'fsa', 'city_fsa']

# %%
col_remove_str = ['listing_url', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 
              'transit', 'access', 'interaction', 'house_rules', 'picture_url', 'host_url', 'host_name', 'host_location', 
              'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'street', 
              'neighbourhood', 'neighbourhood_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code',
              'country', 'amenities', 'calendar_updated', 'amenities_list', 'fsa']
df.drop(col_remove_str,axis=1,inplace=True)
removed_columns_record.append(col_remove_str)

# %%
#remove irrelevant numeric columns
l_num = []
for col in df.columns:
    if df[col].dtype.name in ['int64','float64']:
        l_num.append(col)
print(l_num)
# Out:
# ['id', 'scrape_id', 'host_id', 'host_response_rate', 'host_listings_count', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month', 'days_sincehost_since', 'days_sincefirst_review', 'days_sincelast_review']

# %%
col_remove_num = ['id', 'scrape_id', 'host_id','minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 
                  'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm']
df.drop(col_remove_num,axis=1,inplace=True)
removed_columns_record.append(col_remove_num)

# %%
#remove irrelevant 
l_dt = []
for col in df.columns:
    if df[col].dtype == '<M8[ns]':
        l_dt.append(col)
print(l_dt)
# Out:
# ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']

# %%
col_remove_dt = ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']
df.drop(col_remove_dt,axis=1,inplace=True)
removed_columns_record.append(col_remove_dt)

# %%
#Final inspection
df.head()
# Out:
#    host_response_time  host_response_rate  host_is_superhost  \
# 0      within an hour                1.00              False
# 1  a few days or more                0.00              False
# 2      within an hour                1.00              False
# 3      within an hour                1.00               True
# 4  within a few hours                0.79              False
#
#    host_listings_count  host_has_profile_pic  host_identity_verified  \
# 0                  1.0                  True                    True
# 1                  2.0                  True                   False
# 2                  1.0                  True                    True
# 3                  2.0                  True                    True
# 4                  7.0                  True                    True
#
#    latitude  longitude  is_location_exact property_type        room_type  \
# 0  43.64617  -79.42451              False         House  Entire home/apt
# 1  43.64105  -79.37628               True     Apartment     Private room
# 2  43.66724  -79.41598               True         House     Private room
# 3  43.69602  -79.45468               True         House     Private room
# 4  43.64530  -79.38940               True   Condominium  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  price  \
# 0            10        3.0       5.0   7.0       Real Bed  468.0
# 1             2        1.5       1.0   1.0       Real Bed  100.0
# 2             1        1.5       1.0   1.0  Pull-out Sofa   67.0
# 3             3        1.0       1.0   1.0       Real Bed   72.0
# 4             5        1.0       1.0   2.0       Real Bed  199.0
#
#    security_deposit  cleaning_fee  guests_included  extra_people  \
# 0            1000.0         150.0                1           0.0
# 1            2679.0           0.0                1           0.0
# 2             134.0          27.0                1          20.0
# 3               0.0           0.0                2          20.0
# 4             300.0          51.0                2          18.0
#
#    minimum_nights  maximum_nights  has_availability  availability_30  \
# 0               4             730              True                0
# 1             180             365              True                0
# 2               1              10              True                0
# 3               1              28              True               11
# 4               4             730              True                8
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0                0                0                 0                  7
# 1                0                0                 0                169
# 2                0                0                 0                  0
# 3               23               47               223                209
# 4               32               46               321                 37
#
#    number_of_reviews_ltm  review_scores_rating  review_scores_accuracy  \
# 0                      0                 100.0                    10.0
# 1                      0                  97.0                    10.0
# 2                      0                  97.0                    10.0
# 3                     12                  95.0                    10.0
# 4                      6                  95.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                    9.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                     9.0                 10.0
# 4                         10.0                    10.0                  9.0
#
#    requires_license  instant_bookable  is_business_travel_ready  \
# 0             False             False                     False
# 1             False              True                     False
# 2             False             False                     False
# 3             False              True                     False
# 4             False             False                     False
#
#            cancellation_policy  require_guest_profile_picture  \
# 0  strict_14_with_grace_period                          False
# 1  strict_14_with_grace_period                          False
# 2                     moderate                          False
# 3  strict_14_with_grace_period                          False
# 4  strict_14_with_grace_period                          False
#
#    require_guest_phone_verification  calculated_host_listings_count  \
# 0                             False                               1
# 1                              True                               2
# 2                             False                               1
# 3                             False                               2
# 4                             False                               7
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            0
# 4                                            7
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
# 2                                             1
# 3                                             2
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0               0.15
# 1                                            0               1.42
# 2                                            0               1.01
# 3                                            0               1.90
# 4                                            0               0.36
#
#    host_is_superhost_NA  host_has_profile_pic_NA  host_identity_verified_NA  \
# 0                 False                    False                      False
# 1                 False                    False                      False
# 2                 False                    False                      False
# 3                 False                    False                      False
# 4                 False                    False                      False
#
#    host_listings_count_NA  bathrooms_NA  host_response_rate_NA  bedrooms_NA  \
# 0                   False         False                   True        False
# 1                   False         False                  False        False
# 2                   False         False                   True        False
# 3                   False         False                  False        False
# 4                   False         False                  False        False
#
#    beds_NA  security_deposit_NA  cleaning_fee_NA  review_scores_rating_NA  \
# 0    False                False            False                    False
# 1    False                False             True                    False
# 2    False                False            False                     True
# 3    False                False            False                    False
# 4    False                False            False                    False
#
#    review_scores_accuracy_NA  review_scores_cleanliness_NA  \
# 0                      False                         False
# 1                      False                         False
# 2                       True                          True
# 3                      False                         False
# 4                      False                         False
#
#    review_scores_checkin_NA  review_scores_communication_NA  \
# 0                     False                           False
# 1                     False                           False
# 2                      True                            True
# 3                     False                           False
# 4                     False                           False
#
#    review_scores_location_NA  review_scores_value_NA  reviews_per_month_NA  \
# 0                      False                   False                 False
# 1                      False                   False                 False
# 2                       True                    True                  True
# 3                      False                   False                 False
# 4                      False                   False                 False
#
#    host_response_time_NA  host_since_NA  first_review_NA  last_review_NA  \
# 0                      1              0                0               0
# 1                      0              0                0               0
# 2                      1              0                1               1
# 3                      0              0                0               0
# 4                      0              0                0               0
#
#    amenities_formal dining area  amenities_bathtub with bath chair  \
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
#
#    amenities_espresso machine  amenities_cat(s)  \
# 0                       False             False
# 1                       False             False
# 2                       False              True
# 3                       False             False
# 4                       False             False
#
#    amenities_high-resolution computer monitor  amenities_stove  \
# 0                                       False            False
# 1                                       False            False
# 2                                       False            False
# 3                                       False             True
# 4                                       False             True
#
#    amenities_iron  amenities_hot water  amenities_private hot tub  \
# 0           False                False                      False
# 1           False                False                      False
# 2           False                False                      False
# 3            True                 True                      False
# 4            True                 True                      False
#
#    amenities_essentials  amenities_wide entrance for guests  \
# 0                  True                               False
# 1                 False                               False
# 2                 False                               False
# 3                  True                               False
# 4                  True                               False
#
#    amenities_heated towel rack  amenities_double oven  amenities_private pool  \
# 0                        False                  False                   False
# 1                        False                  False                   False
# 2                        False                  False                   False
# 3                        False                  False                   False
# 4                        False                  False                   False
#
#    amenities_walk-in shower  amenities_pillow-top mattress  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    amenities_garden or backyard  amenities_rain shower  \
# 0                         False                  False
# 1                         False                  False
# 2                         False                  False
# 3                         False                  False
# 4                         False                  False
#
#    amenities_table corner guards  amenities_lockbox  amenities_ski-in/ski-out  \
# 0                          False              False                     False
# 1                          False              False                     False
# 2                          False              False                     False
# 3                          False              False                     False
# 4                          False              False                     False
#
#    amenities_netflix  amenities_mobile hoist  amenities_dryer  \
# 0              False                   False             True
# 1              False                   False            False
# 2              False                   False            False
# 3              False                   False             True
# 4              False                   False             True
#
#    amenities_soaking tub  amenities_pets live on this property  \
# 0                  False                                 False
# 1                  False                                 False
# 2                  False                                  True
# 3                  False                                 False
# 4                  False                                 False
#
#    amenities_internet  amenities_hair dryer  amenities_memory foam mattress  \
# 0                True                 False                           False
# 1                True                 False                           False
# 2                True                 False                           False
# 3                True                  True                           False
# 4                True                  True                           False
#
#    amenities_wide clearance to shower  amenities_game console  amenities_crib  \
# 0                               False                   False           False
# 1                               False                   False           False
# 2                               False                   False           False
# 3                               False                   False           False
# 4                               False                   False           False
#
#    amenities_bathtub  amenities_bathroom essentials  amenities_warming drawer  \
# 0              False                          False                     False
# 1              False                          False                     False
# 2              False                          False                     False
# 3              False                          False                     False
# 4              False                          False                     False
#
#    amenities_patio or balcony  amenities_beach view  amenities_sauna  \
# 0                       False                 False            False
# 1                       False                 False            False
# 2                       False                 False            False
# 3                       False                 False            False
# 4                        True                 False            False
#
#    amenities_changing table  amenities_private gym  amenities_elevator  \
# 0                     False                  False               False
# 1                     False                  False                True
# 2                     False                  False               False
# 3                     False                  False               False
# 4                     False                  False                True
#
#    amenities_toilet paper  amenities_smart tv  amenities_cooking basics  \
# 0                   False               False                     False
# 1                   False               False                     False
# 2                   False               False                     False
# 3                   False               False                      True
# 4                   False               False                      True
#
#    amenities_translation missing: en.hosting_amenity_50  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    amenities_roll-in shower  amenities_accessible-height toilet  \
# 0                     False                               False
# 1                     False                               False
# 2                     False                               False
# 3                     False                               False
# 4                     False                               False
#
#    amenities_shared hot tub  amenities_bbq grill  amenities_pocket wifi  \
# 0                     False                False                  False
# 1                     False                False                  False
# 2                     False                False                  False
# 3                     False                False                   True
# 4                     False                False                  False
#
#    amenities_outdoor kitchen  amenities_wifi  amenities_ceiling hoist  \
# 0                      False            True                    False
# 1                      False            True                    False
# 2                      False            True                    False
# 3                      False            True                    False
# 4                      False            True                    False
#
#    amenities_touchless faucets  amenities_hot tub  \
# 0                        False              False
# 1                        False              False
# 2                        False              False
# 3                        False              False
# 4                        False              False
#
#    amenities_babysitter recommendations  amenities_fax machine  \
# 0                                 False                  False
# 1                                 False                  False
# 2                                 False                  False
# 3                                 False                  False
# 4                                 False                  False
#
#    amenities_window guards  amenities_heated floors  amenities_building staff  \
# 0                    False                    False                     False
# 1                    False                    False                     False
# 2                    False                    False                     False
# 3                    False                    False                     False
# 4                    False                    False                      True
#
#    amenities_waterfront  amenities_wine cooler  amenities_refrigerator  \
# 0                 False                  False                   False
# 1                 False                  False                   False
# 2                 False                  False                   False
# 3                 False                  False                    True
# 4                 False                  False                    True
#
#    amenities_shared pool  amenities_luggage dropoff allowed  \
# 0                  False                              False
# 1                  False                              False
# 2                  False                              False
# 3                  False                              False
# 4                  False                               True
#
#    amenities_high chair  amenities_bidet  amenities_long term stays allowed  \
# 0                 False            False                              False
# 1                 False            False                              False
# 2                 False            False                              False
# 3                 False            False                               True
# 4                 False            False                               True
#
#    amenities_dog(s)  amenities_hangers  amenities_extra pillows and blankets  \
# 0             False              False                                 False
# 1             False              False                                 False
# 2             False              False                                 False
# 3             False               True                                  True
# 4             False               True                                  True
#
#    amenities_ toilet  amenities_ceiling fan  amenities_air conditioning  \
# 0              False                  False                        True
# 1              False                  False                        True
# 2              False                  False                       False
# 3              False                  False                        True
# 4              False                  False                        True
#
#    amenities_paid parking on premises  amenities_ev charger  \
# 0                               False                 False
# 1                               False                 False
# 2                               False                 False
# 3                               False                 False
# 4                                True                 False
#
#    amenities_fire extinguisher  amenities_well-lit path to entrance  \
# 0                         True                                False
# 1                        False                                False
# 2                        False                                False
# 3                         True                                False
# 4                         True                                False
#
#    amenities_suitable for events  amenities_family/kid friendly  \
# 0                          False                           True
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                           True
#
#    amenities_free parking on premises  amenities_buzzer/wireless intercom  \
# 0                               False                               False
# 1                                True                                True
# 2                               False                               False
# 3                                True                               False
# 4                               False                               False
#
#    amenities_carbon monoxide detector  amenities_fire pit  \
# 0                               False               False
# 1                               False               False
# 2                               False               False
# 3                                True               False
# 4                                True               False
#
#    amenities_cleaning before checkout  amenities_free street parking  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                           True
# 4                               False                          False
#
#    amenities_outdoor seating  amenities_wheelchair accessible  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                      False                             True
#
#    amenities_balcony  amenities_single level home  amenities_gym  \
# 0              False                        False          False
# 1              False                        False           True
# 2              False                        False          False
# 3              False                        False          False
# 4              False                         True           True
#
#    amenities_breakfast table  amenities_pool  amenities_shampoo  \
# 0                      False           False               True
# 1                      False            True               True
# 2                      False           False              False
# 3                      False           False              False
# 4                      False            True               True
#
#    amenities_projector and screen  amenities_private living room  \
# 0                           False                          False
# 1                           False                          False
# 2                           False                          False
# 3                           False                          False
# 4                           False                          False
#
#    amenities_translation missing: en.hosting_amenity_49  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    amenities_children’s books and toys  amenities_air purifier  \
# 0                                False                   False
# 1                                False                   False
# 2                                False                   False
# 3                                False                   False
# 4                                False                   False
#
#    amenities_24-hour check-in  amenities_heat lamps  \
# 0                       False                 False
# 1                       False                 False
# 2                       False                 False
# 3                        True                 False
# 4                        True                 False
#
#    amenities_convection oven  amenities_terrace  amenities_amazon echo  \
# 0                      False              False                  False
# 1                      False              False                  False
# 2                      False              False                  False
# 3                      False              False                  False
# 4                      False              False                  False
#
#    amenities_smoking allowed  amenities_wide entryway  amenities_dvd player  \
# 0                      False                    False                 False
# 1                      False                    False                 False
# 2                      False                    False                 False
# 3                      False                    False                 False
# 4                      False                    False                 False
#
#    amenities_paid parking off premises  amenities_beachfront  \
# 0                                False                 False
# 1                                False                 False
# 2                                False                 False
# 3                                False                 False
# 4                                False                 False
#
#    amenities_stair gates  amenities_pool toys  amenities_coffee maker  \
# 0                  False                False                   False
# 1                  False                False                   False
# 2                  False                False                   False
# 3                  False                False                    True
# 4                  False                False                    True
#
#    amenities_electric profiling bed  amenities_hammock  \
# 0                             False              False
# 1                             False              False
# 2                             False              False
# 3                             False              False
# 4                             False              False
#
#    amenities_self check-in  amenities_outdoor parking  amenities_murphy bed  \
# 0                    False                      False                 False
# 1                    False                      False                 False
# 2                    False                      False                 False
# 3                     True                      False                 False
# 4                     True                      False                 False
#
#    amenities_lock on bedroom door  amenities_safety card  \
# 0                           False                  False
# 1                           False                  False
# 2                           False                  False
# 3                            True                  False
# 4                           False                  False
#
#    amenities_steam oven  amenities_dishes and silverware  \
# 0                 False                            False
# 1                 False                            False
# 2                 False                            False
# 3                 False                             True
# 4                 False                             True
#
#    amenities_smart lock  amenities_heating  amenities_hot water kettle  \
# 0                 False               True                       False
# 1                 False               True                       False
# 2                 False              False                       False
# 3                 False               True                       False
# 4                 False               True                       False
#
#    amenities_keypad  amenities_mountain view  amenities_first aid kit  \
# 0             False                    False                     True
# 1             False                    False                    False
# 2             False                    False                    False
# 3              True                    False                    False
# 4             False                    False                    False
#
#    amenities_bath towel  amenities_hbo go  amenities_printer  \
# 0                 False             False              False
# 1                 False             False              False
# 2                 False             False              False
# 3                 False             False              False
# 4                 False             False              False
#
#    amenities_no stairs or steps to enter  amenities_en suite bathroom  \
# 0                                  False                        False
# 1                                  False                        False
# 2                                  False                        False
# 3                                   True                        False
# 4                                  False                        False
#
#    amenities_room-darkening shades  amenities_wide doorway to guest bathroom  \
# 0                            False                                     False
# 1                            False                                     False
# 2                            False                                     False
# 3                            False                                     False
# 4                            False                                     False
#
#    amenities_private entrance  amenities_doorman  amenities_washer / dryer  \
# 0                       False              False                     False
# 1                       False               True                     False
# 2                       False              False                     False
# 3                        True              False                     False
# 4                        True               True                     False
#
#    amenities_tv  amenities_microwave  amenities_ground floor access  \
# 0          True                False                          False
# 1          True                False                          False
# 2         False                False                          False
# 3         False                 True                          False
# 4          True                 True                          False
#
#    amenities_mudroom  amenities_pack ’n play/travel crib  \
# 0              False                               False
# 1              False                               False
# 2              False                               False
# 3              False                               False
# 4              False                               False
#
#    amenities_exercise equipment  amenities_central air conditioning  \
# 0                         False                               False
# 1                         False                               False
# 2                         False                               False
# 3                         False                               False
# 4                         False                               False
#
#    amenities_gas oven  amenities_washer  amenities_oven  \
# 0               False              True           False
# 1               False             False           False
# 2               False             False           False
# 3               False              True            True
# 4               False              True            True
#
#    amenities_shower chair  amenities_cable tv  amenities_pool with pool hoist  \
# 0                   False               False                           False
# 1                   False                True                           False
# 2                   False               False                           False
# 3                   False               False                           False
# 4                   False                True                           False
#
#    amenities_shared gym  amenities_breakfast  amenities_firm mattress  \
# 0                 False                False                    False
# 1                 False                False                    False
# 2                 False                False                    False
# 3                 False                False                    False
# 4                 False                False                    False
#
#    amenities_pets allowed  amenities_private bathroom  \
# 0                   False                       False
# 1                   False                       False
# 2                   False                       False
# 3                   False                       False
# 4                    True                       False
#
#    amenities_indoor fireplace  amenities_tennis court  \
# 0                        True                   False
# 1                       False                   False
# 2                        True                   False
# 3                       False                   False
# 4                       False                   False
#
#    amenities_laptop friendly workspace  amenities_bed linens  \
# 0                                False                 False
# 1                                False                 False
# 2                                False                 False
# 3                                 True                  True
# 4                                 True                  True
#
#    amenities_wide hallways  amenities_accessible-height bed  \
# 0                    False                            False
# 1                    False                            False
# 2                    False                            False
# 3                    False                            False
# 4                    False                            False
#
#    amenities_beach essentials  amenities_brick oven  amenities_baby monitor  \
# 0                       False                 False                   False
# 1                       False                 False                   False
# 2                       False                 False                   False
# 3                       False                 False                   False
# 4                       False                 False                   False
#
#    amenities_mini fridge  amenities_kitchenette  amenities_pool cover  \
# 0                  False                  False                 False
# 1                  False                  False                 False
# 2                  False                  False                 False
# 3                  False                  False                 False
# 4                  False                  False                 False
#
#    amenities_bedroom comforts  amenities_full kitchen  \
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                   False
#
#    amenities_smoke detector  amenities_flat path to guest entrance  \
# 0                      True                                  False
# 1                      True                                  False
# 2                     False                                  False
# 3                      True                                  False
# 4                      True                                  False
#
#    amenities_sound system  amenities_fireplace guards  \
# 0                   False                       False
# 1                   False                       False
# 2                   False                       False
# 3                   False                       False
# 4                   False                       False
#
#    amenities_children’s dinnerware  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    amenities_extra space around shower and toilet  amenities_sun loungers  \
# 0                                           False                   False
# 1                                           False                   False
# 2                                           False                   False
# 3                                           False                   False
# 4                                           False                   False
#
#    amenities_day bed  amenities_other  amenities_host greets you  \
# 0              False            False                      False
# 1              False            False                      False
# 2              False            False                      False
# 3              False            False                      False
# 4              False            False                      False
#
#    amenities_baby bath  amenities_ethernet connection  \
# 0                False                          False
# 1                False                          False
# 2                False                          False
# 3                False                          False
# 4                False                          False
#
#    amenities_outlet covers  amenities_wide entrance  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
#
#    amenities_extra space around bed  amenities_fixed grab bars for toilet  \
# 0                             False                                 False
# 1                             False                                 False
# 2                             False                                 False
# 3                             False                                 False
# 4                             False                                 False
#
#    amenities_alfresco bathtub  amenities_dishwasher  amenities_kitchen  \
# 0                       False                 False               True
# 1                       False                 False              False
# 2                       False                 False              False
# 3                       False                 False               True
# 4                       False                  True               True
#
#    amenities_other pet(s)  amenities_jetted tub  \
# 0                   False                 False
# 1                   False                 False
# 2                   False                 False
# 3                   False                 False
# 4                   False                 False
#
#    amenities_disabled parking spot  amenities_stand alone steam shower  \
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                            False                               False
# 4                            False                               False
#
#    amenities_body soap  amenities_lake access  \
# 0                False                  False
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                  False
#
#    amenities_fixed grab bars for shower  amenities_standing valet  \
# 0                                 False                     False
# 1                                 False                     False
# 2                                 False                     False
# 3                                 False                     False
# 4                                 False                     False
#
#            city_fsa  city_fsa_NA  days_sincehost_since  \
# 0      West Toronto        False                  3975
# 1  Downtown Toronto        False                  3657
# 2  Downtown Toronto        False                  3532
# 3              York        False                  3391
# 4  Downtown Toronto        False                  3350
#
#    days_sincefirst_review  days_sincelast_review
# 0                    1439                    570
# 1                    3598                   2130
# 2                     533                     58
# 3                    3314                     65
# 4                    3095                     44

# %%
df.shape
# Out:
# (20766, 271)

# %%
# Export data
df.to_csv('data/df_cleaned.csv')

# %% [markdown]
# # 7. Conclusion

# %% [markdown]
# In this section, the following data wrangling steps where performed:
#     1. Remove columns with excessive missing values;
#     2. Inspect and address outliers;
#     3. Impute data;
#     4. Create new features; and
#     5. Remove irrelevant features
# The next step of this project is data visualization which will be presented in subsequent notebooks.
